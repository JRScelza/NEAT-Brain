# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/jeromescelza/Library/CloudStorage/OneDrive-JohnsHopkins/Game Theory/NEAT-Brain/data/cloutier_2009_data.csv")
df.head()
# Out:
#    environment | time (s)  ADPg | ADPg (mM)  ADPn | ADPn (mM)  \
# 0                       0          0.130710          0.113592
# 1                       1          0.130563          0.113612
# 2                       2          0.130450          0.113612
# 3                       3          0.130364          0.113612
# 4                       4          0.130297          0.113612
#
#    AMPg | AMPg (mM)  AMPn | AMPn (mM)  ATPg | ATPg (mM)  ATPg | ATPg' (mM/s)  \
# 0          0.008290          0.006208           2.24000             0.000190
# 1          0.008271          0.006210           2.24017             0.000145
# 2          0.008257          0.006210           2.24029             0.000111
# 3          0.008245          0.006210           2.24039             0.000086
# 4          0.008237          0.006210           2.24047             0.000066
#
#    ATPn | ATPn (mM)  ATPn | ATPn' (mM/s)  BOLD | BOLD (dimensionless)  ...  \
# ...

# %%
f = plt.figure()
plt.plot(range(len(df['ADPg | ADPg (mM)'])), df['ADPg | ADPg (mM)'])
plt.show()

# %%
# %matplotlib inline

fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(15, 5))
plt.subplots_adjust(hspace=0.5)
count = 0

for i in df.columns:
    
    if count <5:
        axs[count].plot(df[i],c=np.random.rand(3,), label=i)
        axs[count].legend()
        count +=1
        
    else:
        count = 0
        fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(15, 5))
        plt.subplots_adjust(hspace=0.5)
# Out:
# /var/folders/pc/n9rhstx569n8y94hqm9vklb40000gn/T/ipykernel_65686/204400547.py:19: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(15, 5))
# 2023-04-11 20:38:44.255 python[65686:13348583] IMKClient Stall detected, *please Report* your user scenario attaching a spindump (or sysdiagnose) that captures the problem - (imkxpc_bundleIdentifierWithReply:) block performed very slowly (1.13 secs).
# 2023-04-11 20:38:49.364 python[65686:13348583] +[CATransaction synchronize] called within transaction
# 2023-04-11 20:38:56.665 python[65686:13348583] +[CATransaction synchronize] called within transaction
# 2023-04-11 20:39:00.461 python[65686:13348583] +[CATransaction synchronize] called within transaction
# ...
